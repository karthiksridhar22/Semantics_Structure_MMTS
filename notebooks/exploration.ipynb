# %%
import sys, os
from pathlib import Path
from types import SimpleNamespace

os.chdir('/home/karthik/Semantics_Structure_MMTS')

# %%
# Out:
# PosixPath('/home/karthik/Semantics_Structure_MMTS/notebooks')
